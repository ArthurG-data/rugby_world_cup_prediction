# %% [markdown]
# # The Library

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression
import re
from sklearn import discriminant_analysis
from sklearn.preprocessing import LabelEncoder
from fitter import Fitter, get_common_distributions, get_distributions

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # The Necessary Files

# %%
current_dir = os.getcwd()
folder = '/data/results_international/'
result_file = 'adj_final_results.csv'
rubicology_file = 'all_games_RWC2023_fixed.csv'

# %% [markdown]
# # Expected score gap by elo gap/ relation between elo and score against or for?

# %%
result_df = pd.read_csv(current_dir+folder+result_file)
result_df['date'] = pd.to_datetime(result_df['date'])
result_df['point_gap'] = result_df.apply(lambda row: abs(row['Score A']-row['Score B']) , axis=1)
result_df.head(2)
# Out:
#    Unnamed: 0       date    Team A   Team B  Score A  Score B  \
# 0           0 1882-12-16     Wales  England        0        2
# 1           1 1883-01-08  Scotland    Wales        3        1
#
#                        Tourn Venue       City  Neut.  Country  elo_home  \
# 0  Home_Nations_Championship   NaN    Swansea   True      NaN    1000.0
# 1  Home_Nations_Championship   NaN  Edinburgh   True      NaN    1000.0
#
#      elo_away  proba_home_win   elo_gap  outcome  point_gap
# 0  1000.00000        0.500000   0.00000      0.0          2
# 1   982.97151        0.524486  17.02849      1.0          2

# %%
#relationship between point gap and elo gap
result_positive_elo_gap = result_df
result_positive_elo_gap["elo_gap"] = result_positive_elo_gap["elo_gap"].abs()

# %%
elo_gap_ax = sns.regplot(data=result_positive_elo_gap, y="point_gap", x="elo_gap")
elo_gap_ax.set(title='Relationship Between score gap and Elo Gap')
elo_gap_ax.set(ylabel='Point Gap', xlabel='Elo Gap')
# Out:
# [Text(0, 0.5, 'Point Gap'), Text(0.5, 0, 'Elo Gap')]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

grouped_result = result_positive_elo_gap.groupby('elo_gap')['point_gap'].median().reset_index()
result_positive_elo_gap["elo_gap"] = (result_positive_elo_gap["elo_gap"] /10).round(0)*10
X = np.array(grouped_result['elo_gap']).reshape(-1, 1)
Y = np.array(grouped_result['point_gap']).reshape(-1, 1)


grouped_result = grouped_result[grouped_result['elo_gap']<800]
# Assuming result_positive_elo_gap contains your data
x_data = grouped_result['elo_gap']
y_data = grouped_result['point_gap']

# Define the function
def custom_func(x, z, b, k):
    return z * (b ** (k * x))

# Fit the curve to the data
popt, pcov = curve_fit(custom_func, x_data, y_data)
print(popt)
# Get the optimized parameters
z_opt, b_opt, k_opt = popt

# Generate points for the curve
x_curve = np.linspace(min(x_data), max(x_data), 100)
y_curve = custom_func(x_curve, z_opt, b_opt, k_opt)

# Plot the data and the fitted curve
plt.scatter(x_data, y_data, label='Data')
plt.plot(x_curve, y_curve, 'r-', label='Fitted Curve')
plt.xlabel('Elo Gap')
plt.ylabel('Point Gap')
plt.title('Fitting z * b^(kx) to Data')
plt.legend()
plt.show()
# Out:
# [11.22398114  1.00385823  0.51257302]

# %%
excluded_tournaments = ['Rugby_World_Cup', 'Rugby_World_Cup_Pool_A', 'Rugby_World_Cup_Pool_B', 'Rugby_World_Cup_Pool_C', 'Rugby_World_Cup_Pool_D']


# Filter train data
result_positive_elo_gap_train = result_positive_elo_gap[
    (~result_positive_elo_gap['Tourn'].isin(excluded_tournaments)) & 
    (result_positive_elo_gap['date'].dt.year != 2023)
]

# Filter test data
result_positive_elo_gap_test = result_positive_elo_gap[
    (result_positive_elo_gap['Tourn'].isin(excluded_tournaments)) & 
    (result_positive_elo_gap['date'].dt.year == 2023) 
]
#estimate point gap
X = np.array(result_positive_elo_gap_train['elo_gap']).reshape(-1,1)
y= np.array(result_positive_elo_gap_train['point_gap']).reshape(-1,1)
X_test = np.array(result_positive_elo_gap_test['elo_gap']).reshape(-1,1)
Y_test = np.array(result_positive_elo_gap_test['point_gap']).reshape(-1,1)

# %%
#plot the elo gaps
sns.histplot(data=result_positive_elo_gap_train, x='elo_gap')
# Out:
# <Axes: xlabel='elo_gap', ylabel='Count'>

# %%
# Group by score gaps, then count occurrences
score_gap_counts_total = result_positive_elo_gap_train.groupby('point_gap').size().reset_index(name='Count')

# Calculate the total count of score gaps
total_gap_counts = score_gap_counts_total['Count'].sum()

# Calculate the probability of each score gap happening
score_gap_counts_total['Probability'] = score_gap_counts_total['Count'] / total_gap_counts

# Plot the line plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=score_gap_counts_total, x='point_gap', y='Probability')
plt.xlabel('Score Gap')
plt.ylabel('Probability')
plt.title('Probability Distribution of Score Gap')
plt.show()

# %%
#do the same, but only take the score that represent 95% of the possibilities
# Calculate the cumulative probability
topN = 1

score_gap_counts_total['Cumulative Probability'] = score_gap_counts_total['Probability'].cumsum()
# Filter the DataFrame to include only the scores representing the top 95% of probabilities
top_N_percent_scores = score_gap_counts_total[score_gap_counts_total['Cumulative Probability'] <= topN]
# Plot the line plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=top_N_percent_scores, x='point_gap', y='Probability')
plt.xlabel('Score Gap')
# Out:
# Text(0.5, 0, 'Score Gap')

# %%
from fitter import Fitter, get_common_distributions, get_distributions

f = Fitter(result_positive_elo_gap_train['point_gap'])
f.fit()
f.summary()
# Out:
# 2024-05-10 16:26:50.190 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED _fit distribution (taking more than 30 seconds)
# 2024-05-10 16:26:50.959 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=0.006861)
# 2024-05-10 16:26:51.705 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted anglit distribution with error=0.017949)
# 2024-05-10 16:26:53.142 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cosine distribution with error=0.016737)
# 2024-05-10 16:26:54.462 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted arcsine distribution with error=0.013639)
# 2024-05-10 16:26:55.183 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted argus distribution with error=0.019649)
# 2024-05-10 16:26:55.209 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted bradford distribution with error=0.012845)
# 2024-05-10 16:26:55.254 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=0.002562)
# 2024-05-10 16:26:55.569 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted alpha distribution with error=0.003663)
# 2024-05-10 16:26:56.210 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=0.002661)
# 2024-05-10 16:26:57.331 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi distribution with error=0.00333)
# 2024-05-10 16:26:58.215 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dweibull distribution with error=0.008395)
# 2024-05-10 16:26:58.330 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted betaprime distribution with error=0.003512)
# 2024-05-10 16:26:58.880 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dgamma distribution with error=0.008511)
# 2024-05-10 16:26:58.910 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted beta distribution with error=0.002623)
# 2024-05-10 16:26:59.298 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted crystalball distribution with error=0.010735)
# 2024-05-10 16:26:59.318 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr12 distribution with error=0.003862)
# 2024-05-10 16:27:00.151 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted fatiguelife distribution with error=0.00227)
# 2024-05-10 16:27:01.295 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponnorm distribution with error=0.002552)
# 2024-05-10 16:27:01.316 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted erlang distribution with error=0.018762)
# 2024-05-10 16:27:02.310 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted foldcauchy distribution with error=0.013856)
# 2024-05-10 16:27:04.235 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=0.00458)
# 2024-05-10 16:27:05.318 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=0.002995)
# 2024-05-10 16:27:08.970 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted foldnorm distribution with error=0.005959)
# 2024-05-10 16:27:09.559 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted f distribution with error=0.030517)
# 2024-05-10 16:27:11.929 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genextreme distribution with error=0.003314)
# 2024-05-10 16:27:11.996 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genhalflogistic distribution with error=0.004147)
# 2024-05-10 16:27:12.013 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponweib distribution with error=0.003177)
# 2024-05-10 16:27:13.183 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr distribution with error=0.002845)
# 2024-05-10 16:27:13.432 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gumbel_l distribution with error=0.014608)
# 2024-05-10 16:27:13.618 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gumbel_r distribution with error=0.006931)
# 2024-05-10 16:27:13.637 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gennorm distribution with error=0.007186)
# 2024-05-10 16:27:13.719 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfcauchy distribution with error=0.002352)
# 2024-05-10 16:27:14.074 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halflogistic distribution with error=0.004138)
# 2024-05-10 16:27:14.360 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfnorm distribution with error=0.005959)
# 2024-05-10 16:27:16.643 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genhyperbolic distribution with error=0.00295)
# 2024-05-10 16:27:17.385 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted hypsecant distribution with error=0.008324)
# 2024-05-10 16:27:18.254 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted geninvgauss distribution with error=0.002442)
# 2024-05-10 16:27:18.503 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gibrat distribution with error=0.002669)
# 2024-05-10 16:27:19.530 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invgauss distribution with error=0.002567)
# 2024-05-10 16:27:19.742 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted fisk distribution with error=0.02665)
# 2024-05-10 16:27:20.113 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invgamma distribution with error=0.003216)
# 2024-05-10 16:27:20.831 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfgennorm distribution with error=0.002348)
# 2024-05-10 16:27:21.191 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genpareto distribution with error=0.037319)
# 2024-05-10 16:27:22.480 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ksone distribution with error=0.018941)
# 2024-05-10 16:27:22.536 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED kstwo distribution (taking more than 30 seconds)
# 2024-05-10 16:27:22.793 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genlogistic distribution with error=0.006902)
# 2024-05-10 16:27:22.828 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invweibull distribution with error=0.003314)
# 2024-05-10 16:27:22.863 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted laplace distribution with error=0.007329)
# 2024-05-10 16:27:22.942 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted jf_skew_t distribution with error=0.004449)
# 2024-05-10 16:27:23.491 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gengamma distribution with error=0.002549)
# 2024-05-10 16:27:23.641 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genexpon distribution with error=0.002563)
# 2024-05-10 16:27:23.987 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gompertz distribution with error=0.002556)
# 2024-05-10 16:27:24.255 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted logistic distribution with error=0.008908)
# 2024-05-10 16:27:25.811 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy distribution with error=0.00357)
# 2024-05-10 16:27:27.311 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kstwobign distribution with error=0.007697)
# 2024-05-10 16:27:29.137 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy_l distribution with error=0.021443)
# 2024-05-10 16:27:29.300 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted laplace_asymmetric distribution with error=0.00276)
# 2024-05-10 16:27:31.856 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gausshyper distribution with error=0.005138)
# 2024-05-10 16:27:32.790 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kappa3 distribution with error=0.002559)
# 2024-05-10 16:27:32.995 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted maxwell distribution with error=0.009439)
# 2024-05-10 16:27:33.012 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED multivariate_normal distribution (taking more than 30 seconds)
# 2024-05-10 16:27:34.414 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted moyal distribution with error=0.00586)
# 2024-05-10 16:27:36.361 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lomax distribution with error=0.015282)
# 2024-05-10 16:27:38.891 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loggamma distribution with error=0.010904)
# 2024-05-10 16:27:39.421 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loguniform distribution with error=0.013129)
# 2024-05-10 16:27:39.546 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=0.010735)
# 2024-05-10 16:27:39.650 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted johnsonsb distribution with error=0.002237)
# 2024-05-10 16:27:39.976 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted pareto distribution with error=0.002322)
# 2024-05-10 16:27:41.063 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loglaplace distribution with error=0.023469)
# 2024-05-10 16:27:44.121 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=0.02232)
# 2024-05-10 16:27:47.196 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted johnsonsu distribution with error=0.002553)
# 2024-05-10 16:27:47.631 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted nakagami distribution with error=0.00371)
# 2024-05-10 16:27:48.150 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=0.009064)
# 2024-05-10 16:27:50.849 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED kappa4 distribution (taking more than 30 seconds)
# 2024-05-10 16:27:53.505 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED levy_stable distribution (taking more than 30 seconds)
# 2024-05-10 16:28:01.874 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED mielke distribution (taking more than 30 seconds)
# 2024-05-10 16:28:03.003 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=0.015909)
# 2024-05-10 16:28:04.432 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED ncf distribution (taking more than 30 seconds)
# 2024-05-10 16:28:04.489 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rv_continuous distribution (taking more than 30 seconds)
# 2024-05-10 16:28:04.501 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rv_histogram distribution (taking more than 30 seconds)
# 2024-05-10 16:28:06.377 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED nct distribution (taking more than 30 seconds)
# 2024-05-10 16:28:08.904 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED ncx2 distribution (taking more than 30 seconds)
# 2024-05-10 16:28:09.560 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED norminvgauss distribution (taking more than 30 seconds)
# 2024-05-10 16:28:09.996 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED pearson3 distribution (taking more than 30 seconds)
# 2024-05-10 16:28:14.138 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED powerlognorm distribution (taking more than 30 seconds)
# 2024-05-10 16:28:17.236 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED powernorm distribution (taking more than 30 seconds)
# 2024-05-10 16:28:18.173 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rdist distribution (taking more than 30 seconds)
# 2024-05-10 16:28:20.913 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted semicircular distribution with error=0.018845)
# 2024-05-10 16:28:20.923 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# 2024-05-10 16:28:23.564 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED reciprocal distribution (taking more than 30 seconds)
# 2024-05-10 16:28:31.920 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rel_breitwigner distribution (taking more than 30 seconds)
# 2024-05-10 16:28:32.884 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rice distribution with error=0.009064)
# 2024-05-10 16:28:36.433 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED skewcauchy distribution (taking more than 30 seconds)
# 2024-05-10 16:28:36.723 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=0.018821)
# 2024-05-10 16:28:37.322 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted vonmises distribution with error=2.360615)
# 2024-05-10 16:28:37.408 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED vonmises_fisher distribution (taking more than 30 seconds)
# 2024-05-10 16:28:38.914 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED skewnorm distribution (taking more than 30 seconds)
# 2024-05-10 16:28:39.621 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED studentized_range distribution (taking more than 30 seconds)
# 2024-05-10 16:28:40.061 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED t distribution (taking more than 30 seconds)
# 2024-05-10 16:28:44.767 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted trapezoid distribution with error=0.024268)
# 2024-05-10 16:28:47.293 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted trapz distribution with error=0.024268)
# 2024-05-10 16:28:47.977 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wald distribution with error=0.002842)
# 2024-05-10 16:28:48.205 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED triang distribution (taking more than 30 seconds)
# 2024-05-10 16:28:50.929 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED truncexpon distribution (taking more than 30 seconds)
# 2024-05-10 16:28:50.979 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED truncnorm distribution (taking more than 30 seconds)
# 2024-05-10 16:28:53.637 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED truncpareto distribution (taking more than 30 seconds)
# 2024-05-10 16:29:01.942 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED truncweibull_min distribution (taking more than 30 seconds)
# 2024-05-10 16:29:02.147 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wrapcauchy distribution with error=0.012652)
# 2024-05-10 16:29:02.900 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED tukeylambda distribution (taking more than 30 seconds)
# 2024-05-10 16:29:07.488 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED vonmises_line distribution (taking more than 30 seconds)
# 2024-05-10 16:29:09.668 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED weibull_max distribution (taking more than 30 seconds)
# 2024-05-10 16:29:10.104 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED weibull_min distribution (taking more than 30 seconds)
#              sumsquare_error          aic          bic  kl_div  ks_statistic  \
# johnsonsb           0.002237  1370.237693  1395.085796     inf      0.040718
# fatiguelife         0.002270  1366.915199  1385.551277     inf      0.039299
# pareto              0.002322  1375.744730  1394.380808     inf      0.041417
# halfgennorm         0.002348  1379.081397  1397.717475     inf      0.051576
# halfcauchy          0.002352  1279.776800  1292.200851     inf      0.064796
#
#                 ks_pvalue
# johnsonsb    9.568446e-06
# fatiguelife  2.212509e-05
# pareto       6.264471e-06
# halfgennorm  5.852476e-09
# halfcauchy   6.790683e-14

# %%
print(f.get_best(method = 'sumsquare_error'))
f.fitted_param["johnsonsb"]
# Out:
# {'johnsonsb': {'a': 2.155749734964961, 'b': 0.8030933549735537, 'loc': -0.6512061182858886, 'scale': 173.5217156413969}}
# (2.155749734964961, 0.8030933549735537, -0.6512061182858886, 173.5217156413969)

# %%
#for each team, is there a lot of variation in score
scores_team_a= result_positive_elo_gap[['Team A','Score A', 'elo_home']].rename(columns={'Team A':'Team', 'Score A': 'Score', 'elo_home':'Elo'})
scores_team_b= result_positive_elo_gap[['Team B','Score B', 'elo_away']].rename(columns={'Team B':'Team', 'Score B': 'Score', 'elo_away':'Elo'})
all_scores = pd.concat([scores_team_a,scores_team_b])[['Team', 'Score', 'Elo']]
sns.histplot(data=all_scores, x='Score')
# Out:
# <Axes: xlabel='Score', ylabel='Count'>

# %%
predicted_y = [custom_func(x, z_opt, b_opt, k_opt ) for x in X]
predicted_y_test =[custom_func(x, z_opt, b_opt, k_opt ) for x in X_test]

rmse_train_linear = np.sqrt(np.mean((predicted_y - y)**2))
rmse_test_linear = np.sqrt(np.mean((predicted_y_test - Y_test)**2))


print(f'rmse train linear: {rmse_train_linear}')
print(f'rmse test linear: {rmse_test_linear}')


result_positive_elo_gap_train['predicted_gap'] = predicted_y
result_positive_elo_gap_test['predicted_gap'] = predicted_y_test
# Out:
# rmse train linear: 18.6753527096679
# rmse test linear: 17.15837272161071

# %%
result_positive_elo_gap_test
# Out:
#       Unnamed: 0       date        Team A        Team B  Score A  Score B  \
# 3961        3961 2023-09-08        France   New Zealand       27       13
# 3962        3962 2023-09-09     Australia       Georgia       35       15
# 3963        3963 2023-09-09       England     Argentina       27       10
# 3964        3964 2023-09-09         Italy       Namibia       52        8
# 3965        3965 2023-09-09       Ireland       Romania       82        8
# 3966        3966 2023-09-10         Wales          Fiji       32       26
# 3967        3967 2023-09-10         Japan         Chile       42       12
# 3968        3968 2023-09-10  South Africa      Scotland       18        3
# 3969        3969 2023-09-14        France       Uruguay       27       12
# 3970        3970 2023-09-15   New Zealand       Namibia       71        3
# 3971        3971 2023-09-16       Ireland         Tonga       59       16
# 3972        3972 2023-09-16         Samoa         Chile       43       10
# 3973        3973 2023-09-16         Wales      Portugal       28        8
# 3974        3974 2023-09-17  South Africa       Romania       76        0
# 3975        3975 2023-09-17       England         Japan       34       12
# 3976        3976 2023-09-17     Australia          Fiji       15       22
# 3977        3977 2023-09-20         Italy       Uruguay       38       17
# 3978        3978 2023-09-21        France       Namibia       96        0
# 3979        3979 2023-09-22     Argentina         Samoa       19       10
# 3980        3980 2023-09-23  South Africa       Ireland        8       13
# 3981        3981 2023-09-23       Georgia      Portugal       18       18
# 3982        3982 2023-09-23       England         Chile       71        0
# 3983        3983 2023-09-24      Scotland         Tonga       45       17
# 3984        3984 2023-09-24         Wales     Australia       40        6
# 3985        3985 2023-09-27       Uruguay       Namibia       36       26
# 3986        3986 2023-09-28         Japan         Samoa       28       22
# 3987        3987 2023-09-29   New Zealand         Italy       96       17
# 3988        3988 2023-09-30     Argentina         Chile       59        5
# 3989        3989 2023-09-30      Scotland       Romania       84        0
# 3990        3990 2023-09-30          Fiji       Georgia       17       12
# 3991        3991 2023-10-01  South Africa         Tonga       49       18
# 3992        3992 2023-10-01     Australia      Portugal       34       14
# 3993        3993 2023-10-05   New Zealand       Uruguay       73        0
# 3994        3994 2023-10-06        France         Italy       60        7
# 3995        3995 2023-10-07       England         Samoa       18       17
# 3996        3996 2023-10-07       Ireland      Scotland       36       14
# 3997        3997 2023-10-07         Wales       Georgia       43       19
# 3998        3998 2023-10-08         Tonga       Romania       45       24
# 3999        3999 2023-10-08         Japan     Argentina       27       39
# 4000        4000 2023-10-08          Fiji      Portugal       23       24
# 4001        4001 2023-10-14         Wales     Argentina       17       29
# 4002        4002 2023-10-14       Ireland   New Zealand       24       28
# 4003        4003 2023-10-15       England          Fiji       30       24
# 4004        4004 2023-10-15        France  South Africa       28       29
# 4005        4005 2023-10-20     Argentina   New Zealand        6       44
# 4006        4006 2023-10-21       England  South Africa       15       16
# 4007        4007 2023-10-27     Argentina       England       23       26
# 4008        4008 2023-10-28   New Zealand  South Africa       11       12
#
#                        Tourn                      Venue               City  \
# 3961  Rugby_World_Cup_Pool_A            Stade de France        Saint-Denis
# 3962  Rugby_World_Cup_Pool_C            Stade de France        Saint-Denis
# 3963  Rugby_World_Cup_Pool_D            Stade Vélodrome          Marseille
# 3964  Rugby_World_Cup_Pool_A    Stade Geoffroy-Guichard      Saint-Étienne
# 3965  Rugby_World_Cup_Pool_B  Nouveau Stade de Bordeaux           Bordeaux
# 3966  Rugby_World_Cup_Pool_C  Nouveau Stade de Bordeaux           Bordeaux
# 3967  Rugby_World_Cup_Pool_D        Stadium de Toulouse           Toulouse
# 3968  Rugby_World_Cup_Pool_B            Stade Vélodrome          Marseille
# 3969  Rugby_World_Cup_Pool_A        Stade Pierre-Mauroy  Villeneuve-d'Ascq
# 3970  Rugby_World_Cup_Pool_A        Stadium de Toulouse           Toulouse
# 3971  Rugby_World_Cup_Pool_B      Stade de la Beaujoire             Nantes
# 3972  Rugby_World_Cup_Pool_D  Nouveau Stade de Bordeaux           Bordeaux
# 3973  Rugby_World_Cup_Pool_C            Allianz Riviera               Nice
# 3974  Rugby_World_Cup_Pool_B  Nouveau Stade de Bordeaux           Bordeaux
# 3975  Rugby_World_Cup_Pool_D            Allianz Riviera               Nice
# 3976  Rugby_World_Cup_Pool_C    Stade Geoffroy-Guichard      Saint-Étienne
# 3977  Rugby_World_Cup_Pool_A            Allianz Riviera               Nice
# 3978  Rugby_World_Cup_Pool_A            Stade Vélodrome          Marseille
# 3979  Rugby_World_Cup_Pool_D    Stade Geoffroy-Guichard      Saint-Étienne
# 3980  Rugby_World_Cup_Pool_B            Stade de France        Saint-Denis
# 3981  Rugby_World_Cup_Pool_C        Stadium de Toulouse           Toulouse
# 3982  Rugby_World_Cup_Pool_D        Stade Pierre-Mauroy  Villeneuve-d'Ascq
# 3983  Rugby_World_Cup_Pool_B            Allianz Riviera               Nice
# 3984  Rugby_World_Cup_Pool_C    Parc Olympique Lyonnais   Décines-Charpieu
# 3985  Rugby_World_Cup_Pool_A    Parc Olympique Lyonnais   Décines-Charpieu
# 3986  Rugby_World_Cup_Pool_D        Stadium de Toulouse           Toulouse
# 3987  Rugby_World_Cup_Pool_A    Parc Olympique Lyonnais   Décines-Charpieu
# 3988  Rugby_World_Cup_Pool_D      Stade de la Beaujoire             Nantes
# 3989  Rugby_World_Cup_Pool_B        Stade Pierre-Mauroy  Villeneuve-d'Ascq
# 3990  Rugby_World_Cup_Pool_C  Nouveau Stade de Bordeaux           Bordeaux
# 3991  Rugby_World_Cup_Pool_B            Stade Vélodrome          Marseille
# 3992  Rugby_World_Cup_Pool_C    Stade Geoffroy-Guichard      Saint-Étienne
# 3993  Rugby_World_Cup_Pool_A    Parc Olympique Lyonnais   Décines-Charpieu
# 3994  Rugby_World_Cup_Pool_A    Parc Olympique Lyonnais   Décines-Charpieu
# 3995  Rugby_World_Cup_Pool_D        Stade Pierre-Mauroy  Villeneuve-d'Ascq
# 3996  Rugby_World_Cup_Pool_B            Stade de France        Saint-Denis
# 3997  Rugby_World_Cup_Pool_C      Stade de la Beaujoire             Nantes
# 3998  Rugby_World_Cup_Pool_B        Stade Pierre-Mauroy  Villeneuve-d'Ascq
# 3999  Rugby_World_Cup_Pool_D      Stade de la Beaujoire             Nantes
# 4000  Rugby_World_Cup_Pool_C        Stadium de Toulouse           Toulouse
# 4001         Rugby_World_Cup         Stade de Marseille          Marseille
# 4002         Rugby_World_Cup            Stade de France        Saint-Denis
# 4003         Rugby_World_Cup         Stade de Marseille          Marseille
# 4004         Rugby_World_Cup            Stade de France        Saint-Denis
# 4005         Rugby_World_Cup            Stade de France        Saint-Denis
# 4006         Rugby_World_Cup            Stade de France        Saint-Denis
# 4007         Rugby_World_Cup            Stade de France        Saint-Denis
# 4008         Rugby_World_Cup            Stade de France        Saint-Denis
#
#       Neut.  Country     elo_home     elo_away  proba_home_win  elo_gap  \
# 3961   True      NaN  1663.837464  1867.245237        0.236691    200.0
# 3962   True      NaN  1475.604812  1445.090649        0.543801     30.0
# 3963   True      NaN  1584.721703  1470.883254        0.658205    110.0
# 3964   True      NaN  1100.789263   803.235925        0.847206    300.0
# 3965   True      NaN  1769.271460  1061.057257        0.983321    710.0
# 3966   True      NaN  1468.536433  1403.992020        0.591833     60.0
# 3967   True      NaN  1328.868770   730.646243        0.969041    600.0
# 3968   True      NaN  1741.154820  1431.484146        0.856019    310.0
# 3969   True      NaN  1722.493700  1032.485255        0.981513    690.0
# 3970   True      NaN  1808.589001   787.353393        0.997209   1020.0
# 3971   True      NaN  1770.960147  1007.729390        0.987794    760.0
# 3972   True      NaN  1220.527051   728.055128        0.944533    490.0
# 3973   True      NaN  1492.456609  1102.304527        0.904296    390.0
# 3974   True      NaN  1752.003068  1059.368570        0.981785    690.0
# 3975   True      NaN  1613.840292  1331.459885        0.835554    280.0
# 3976   True      NaN  1518.071955  1380.071845        0.688774    140.0
# 3977   True      NaN  1116.671795  1031.275645        0.620479     90.0
# 3978   True      NaN  1723.703311   787.103231        0.995466    940.0
# 3979   True      NaN  1441.764665  1225.481519        0.776438    220.0
# 3980   True      NaN  1753.868551  1772.023264        0.473897     20.0
# 3981   True      NaN  1402.623506  1094.632526        0.854823    310.0
# 3982   True      NaN  1628.006236   723.100659        0.994563    900.0
# 3983   True      NaN  1420.635899  1006.666273        0.915522    410.0
# 3984   True      NaN  1500.128610  1476.292466        0.534249     20.0
# 3985   True      NaN   996.267893   786.652191        0.769705    210.0
# 3986   True      NaN  1317.293941  1210.952010        0.648432    110.0
# 3987   True      NaN  1808.839163  1151.679547        0.977750    660.0
# 3988   True      NaN  1456.294174   722.589908        0.985565    730.0
# 3989   True      NaN  1428.057707  1057.503087        0.894077    370.0
# 3990   True      NaN  1421.851333  1402.623506        0.527643     20.0
# 3991   True      NaN  1727.761595   999.244465        0.985134    730.0
# 3992   True      NaN  1425.509592  1094.632526        0.870420    330.0
# 3993   True      NaN  1811.166470  1011.897632        0.990058    800.0
# 3994   True      NaN  1724.154351  1149.352240        0.964730    570.0
# 3995   True      NaN  1628.516988  1190.722145        0.925542    440.0
# 3996   True      NaN  1798.130219  1440.542701        0.886798    360.0
# 3997   True      NaN  1550.911484  1376.613965        0.731714    170.0
# 3998   True      NaN   998.044594  1045.018093        0.432809     50.0
# 3999   True      NaN  1337.523806  1457.638944        0.333713    120.0
# 4000   True      NaN  1447.860874  1084.001653        0.890372    360.0
# 4001   True      NaN  1575.717164  1482.799892        0.630619     90.0
# 4002   True      NaN  1807.595110  1812.139522        0.493460      0.0
# 4003   True      NaN  1629.851363  1431.444133        0.758069    200.0
# 4004   True      NaN  1727.612274  1728.961466        0.498058      0.0
# 4005   True      NaN  1530.910638  1836.708783        0.146751    310.0
# 4006   True      NaN  1643.238111  1739.656967        0.364698    100.0
# 4007   True      NaN  1516.278011  1635.730670        0.334562    120.0
# 4008   True      NaN  1851.341410  1747.164408        0.645586    100.0
#
#       outcome  point_gap         predicted_gap
# 3961      1.0         14   [9.582041221594165]
# 3962      1.0         20   [5.642424507111889]
# 3963      1.0         17   [7.239314049861749]
# 3964      1.0         44  [13.084213135751158]
# 3965      1.0         74   [46.92830496918988]
# 3966      1.0          6    [6.19516146163752]
# 3967      1.0         30   [33.31319870864437]
# 3968      1.0         15  [13.498222029265417]
# 3969      1.0         15   [44.09374162397112]
# 3970      1.0         68   [123.2629481633522]
# 3971      1.0         43   [54.83775356031725]
# 3972      1.0         33   [23.64818437252802]
# 3973      1.0         20   [17.31841839646199]
# 3974      1.0         76   [44.09374162397112]
# 3975      1.0         22  [12.293900530597835]
# 3976      0.0          7  [7.9484837331657365]
# 3977      1.0         21   [6.802045022912285]
# 3978      1.0         96   [96.07289789410963]
# 3979      1.0          9  [10.198022125431555]
# 3980      0.0          5   [5.469363646069417]
# 3981      0.5          0  [13.498222029265417]
# 3982      1.0         71   [84.81742055770276]
# 3983      1.0         28  [18.431731809562912]
# 3984      1.0         34   [5.469363646069417]
# 3985      1.0         10   [9.885234867448244]
# 3986      1.0          6   [7.239314049861749]
# 3987      1.0         79   [40.15966490784437]
# 3988      1.0         54  [49.945088036803206]
# 3989      1.0         84    [16.2723513370188]
# 3990      1.0          5   [5.469363646069417]
# 3991      1.0         31  [49.945088036803206]
# 3992      1.0         20  [14.365954364526793]
# 3993      1.0         73   [62.11485640451075]
# 3994      1.0         53   [30.34097012126286]
# 3995      1.0          1  [20.237320753501784]
# 3996      1.0         22  [15.773256111195119]
# 3997      1.0         24   [8.727124313332816]
# 3998      1.0         21   [6.005147403762795]
# 3999      0.0         12   [7.468379440993001]
# 4000      0.0          1  [15.773256111195119]
# 4001      0.0         12   [6.802045022912285]
# 4002      0.0          4   [5.139003158449017]
# 4003      1.0          6   [9.582041221594165]
# 4004      0.0          1   [5.139003158449017]
# 4005      0.0         38  [13.498222029265417]
# 4006      0.0          1    [7.01727440693045]
# 4007      0.0          3   [7.468379440993001]
# 4008      0.0          1    [7.01727440693045]

# %% [markdown]
# # First exploration: Any upsets?

# %%
#Conditions on wins
condition_1 = result_positive_elo_gap_test['elo_gap']>100
condition_2 = (result_positive_elo_gap_test['proba_home_win']<0.5) & (result_positive_elo_gap_test['outcome']>0)
condition_3 = (result_positive_elo_gap_test['proba_home_win']>0.5) & (result_positive_elo_gap_test['outcome']<1)
#conditions on score 
condition_4 = result_positive_elo_gap_test['point_gap'] <result_positive_elo_gap_test['predicted_gap']-7
## we will look at score gap smaller than expectd
upsets = result_positive_elo_gap_test[((condition_1) & (condition_2 |condition_3 )) | (condition_1 & condition_4 ) ]
upsets.head(5)
# Out:
#       Unnamed: 0       date       Team A       Team B  Score A  Score B  \
# 3961        3961 2023-09-08       France  New Zealand       27       13
# 3969        3969 2023-09-14       France      Uruguay       27       12
# 3970        3970 2023-09-15  New Zealand      Namibia       71        3
# 3971        3971 2023-09-16      Ireland        Tonga       59       16
# 3976        3976 2023-09-17    Australia         Fiji       15       22
#
#                        Tourn                    Venue               City  \
# 3961  Rugby_World_Cup_Pool_A          Stade de France        Saint-Denis
# 3969  Rugby_World_Cup_Pool_A      Stade Pierre-Mauroy  Villeneuve-d'Ascq
# 3970  Rugby_World_Cup_Pool_A      Stadium de Toulouse           Toulouse
# 3971  Rugby_World_Cup_Pool_B    Stade de la Beaujoire             Nantes
# 3976  Rugby_World_Cup_Pool_C  Stade Geoffroy-Guichard      Saint-Étienne
#
#       Neut.  Country     elo_home     elo_away  proba_home_win  elo_gap  \
# 3961   True      NaN  1663.837464  1867.245237        0.236691    200.0
# 3969   True      NaN  1722.493700  1032.485255        0.981513    690.0
# 3970   True      NaN  1808.589001   787.353393        0.997209   1020.0
# 3971   True      NaN  1770.960147  1007.729390        0.987794    760.0
# 3976   True      NaN  1518.071955  1380.071845        0.688774    140.0
#
#       outcome  point_gap         predicted_gap
# 3961      1.0         14  [16.656768022835934]
# 3969      1.0         15   [43.81553008426256]
# 3970      1.0         68   [84.04470469162837]
# 3971      1.0         43  [50.307577331132975]
# 3976      0.0          7  [14.796452170378771]

# %% [markdown]
# # PCA Baby

# %%
from sklearn import decomposition
from sklearn import datasets

# %%
rub_wc_df = pd.read_csv(current_dir+'/data/'+rubicology_file )
variables_start = list(rub_wc_df.columns)
variable_end = []
for variable in variables_start:
     if re.search(r'\sA(?!\S)', variable):
        new_variable = re.sub(r'\sA(?!\S)', ' ', variable)
        variable_end.append(new_variable.strip())
variable_a = ['Date', 'Game ID']
variable_b =  ['Date', 'Game ID']

for variable in variable_end:
    if 'Possession' not in variable:
        variable_a.append(f'{variable} A')
    else:
        one, two = variable.split('  - ')
        one = f'{one} A'
        variable = ' - '.join([one, two])
        variable_a.append(variable)

for variable in variable_end:
    if 'Possession' not in variable:
        variable_b.append(f'{variable} B')
    else:
        one, two = variable.split('  - ')
        one = f'{one} B'
        variable = ' - '.join([one, two])
        variable_b.append(variable)
        

rub_wc_df_a = rub_wc_df[variable_a ]
rub_wc_df_b = rub_wc_df[variable_b ]

rub_wc_df_a.columns = rub_wc_df_a.columns.str.replace(r'\sA(?!\S)', '', regex=True)
rub_wc_df_b.columns = rub_wc_df_b.columns.str.replace(r'\sB(?!\S)', '', regex=True)
split_df = pd.concat([rub_wc_df_a,rub_wc_df_b ])
split_df.to_csv(current_dir+folder+'split_df_teams.csv', index=False)

# %%
def do_pca_team(df, n_components=2):
    # Assuming target_names is a list of your categorical target names
    label_encoder = LabelEncoder()
    target_names =df['Team']
    y_encoded = label_encoder.fit_transform(df['Team'])

    pca = decomposition.PCA(n_components)

    X=split_df.drop(columns=['Date','Game ID', 'Team'])

    X_r = pca.fit(X).transform(X)
 
    # Percentage of variance explained for each components
    print(
        "explained variance ratio (first two components): %s"
        % str(pca.explained_variance_ratio_)
    )


    plt.figure()
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
              '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf',
              '#aec7e8', '#ffbb78', '#98df8a', '#ff9896', '#c5b0d5',
              '#c49c94', '#f7b6d2', '#c7c7c7', '#dbdb8d', '#9edae5']
    lw = 2
    
    for color, i, target_name in zip(colors, range(20), target_names):
        plt.scatter(
            X_r[y_encoded == i, 0], X_r[y_encoded == i, 1], color=color, alpha=0.8, lw=lw, label=target_name
        )
    plt.legend(loc="best", shadow=False, scatterpoints=1)
    plt.title("PCA of IRIS dataset")
    plt.show()
    
    return pca

def do_lda_team(df, n_components=2):
    label_encoder = LabelEncoder()
    target_names =df['Team']
    y_encoded = label_encoder.fit_transform(df['Team'])
    lda = discriminant_analysis.LinearDiscriminantAnalysis(n_components=n_components)
    X_r = lda.fit(X, y_encoded).transform(X)
    
    
    plt.figure()
    for color, i, target_name in zip(colors, range(20), target_names):
        plt.scatter(
            X_r[y_encoded == i, 0], X_r[y_encoded == i, 1], alpha=0.8, color=color, label=target_name
        )
    plt.legend(loc="best", shadow=False, scatterpoints=1)
    plt.title("LDA of IRIS dataset")
    
    plt.show()
    return lda

# %%
do_pca_team(split_df)
# Out:
# explained variance ratio (first two components): [0.89994903 0.04599245]
# PCA(n_components=2)

# %%
#create a df with relatice perfomance: the percentage if each action taken by each team
def create_relative_ratio_df(df):
    ids = df['Game ID'].unique()
    for unique_id in ids:
        rows = df[df['Game ID'] == unique_id]
        # sum for each variable across the 2 rows
        sum_row = rows.drop(columns=['Game ID', 'Date', 'Team']).sum(axis=0)
        # divide each row that has the Game ID = id by the sum_rows
        rows.loc[:, ~rows.columns.isin(['Game ID', 'Date', 'Team'])] = rows.drop(columns=['Game ID', 'Date', 'Team']).div(sum_row, axis=1)
        # update the original DataFrame with the scaled values
        df.loc[df['Game ID'] == unique_id, ~df.columns.isin(['Game ID', 'Date', 'Team'])] = rows.drop(columns=['Game ID', 'Date', 'Team']).values
    df.sort_values(by='Game ID', inplace=True)
    df.fillna(0,inplace=True)
    df['Outcome'] = df['Score'].apply(lambda x: 1 if x > 0.5 else (0.5 if x == 0.5 else 0))
    return df

# %%
relative_df_ratio = create_relative_ratio_df(split_df)
relative_df_ratio.reset_index(inplace=True, drop=True)
#ealtive_transpose_ratio = relative_df_ratio.transpose().reset_index(drop=True)
relative_df_ratio.head(5)
# Out:
#          Date  Game ID         Team     Score  Possession - Overall  \
# 0  8-Sep-2023    87834       France  0.675000                  0.49
# 1  8-Sep-2023    87834  New Zealand  0.325000                  0.51
# 2  9-Sep-2023    87835      Namibia  0.133333                  0.48
# 3  9-Sep-2023    87835        Italy  0.866667                  0.52
# 4  9-Sep-2023    87836      Ireland  0.911111                  0.67
#
#    Possession - 1st half  Possession - 2nd half     Tries  Conversions  \
# 0                   0.44                   0.53  0.500000          1.0
# 1                   0.56                   0.47  0.500000          0.0
# 2                   0.53                   0.44  0.125000          0.0
# 3                   0.47                   0.56  0.875000          1.0
# 4                   0.57                   0.76  0.923077          1.0
#
#    Penalties  ...  Total Rucks  Lineouts Successful  Lineouts Thrown  \
# 0   0.833333  ...     0.424460             0.565217         0.560000
# 1   0.166667  ...     0.575540             0.434783         0.440000
# 2   0.500000  ...     0.566434             0.310345         0.363636
# 3   0.500000  ...     0.433566             0.689655         0.636364
# 4   0.000000  ...     0.738095             0.500000         0.545455
#
#    Scrums Successful  Scrums Total  Penalties Conceded Own Half  \
# 0           0.444444      0.416667                     0.222222
# 1           0.555556      0.583333                     0.777778
# 2           0.500000      0.500000                     0.454545
# 3           0.500000      0.500000                     0.545455
# 4           0.500000      0.500000                     0.222222
#
#    Penalties Conceded Opp Half  Yellow Cards  Red Cards  Outcome
# 0                     0.285714           0.0        0.0      1.0
# 1                     0.714286           1.0        0.0      0.0
# 2                     0.727273           1.0        0.0      0.0
# 3                     0.272727           0.0        0.0      1.0
# 4                     0.375000           0.0        0.0      1.0
#
# [5 rows x 34 columns]

# %%
#create a df with relatice perfomance: the percentage if each action taken by each team
def create_relative_diff_df(df):
    ids = df['Game ID'].unique()
    series = []
    for unique_id in ids:
        rows = df[df['Game ID'] == unique_id]
        row_1 = rows.iloc[0].drop(['Game ID', 'Date', 'Team'])
        row_2 = rows.iloc[1].drop(['Game ID', 'Date', 'Team'])
        new_1 = row_1 - row_2
        new_2 = row_2 - row_1
        row_1_header= rows.iloc[0][['Game ID', 'Date', 'Team']]
        row_2_header= rows.iloc[1][['Game ID', 'Date', 'Team']]
        new_1 = pd.concat([row_1_header,new_1 ])
        new_2 = pd.concat([row_2_header,new_2 ])
        
        series.append(new_1)
        series.append(new_2)
        # update the original DataFrame with the scaled values
    df = pd.concat(series, axis=1)
    #df.fillna(0,inplace=True)
    #df['Outcome'] = df['Score'].apply(lambda x: 1 if x > 0.5 else (0.5 if x == 0.5 else 0))
    return df

# %%
relative_df = create_relative_diff_df(split_df)
realtive_transpose = relative_df.transpose().reset_index(drop=True)
realtive_transpose.head(5)
# Out:
#   Game ID         Date          Team Score Possession - Overall  \
# 0   87881  28-Oct-2023   New Zealand    -1                   20
# 1   87881  28-Oct-2023  South Africa     1                  -20
# 2   87880  27-Oct-2023     Argentina    -3                    6
# 3   87880  27-Oct-2023       England     3                   -6
# 4   87879  21-Oct-2023       England    -1                   12
#
#   Possession - 1st half Possession - 2nd half Tries Conversions Penalties  \
# 0                    26                    16     1           0        -2
# 1                   -26                   -16    -1           0         2
# 2                   -10                    18     0           0        -1
# 3                    10                   -18     0           0         1
# 4                     4                    18    -1          -1         1
#
#    ... Rucks Successful Total Rucks Lineouts Successful Lineouts Thrown  \
# 0  ...               59          64                  14              12
# 1  ...              -59         -64                 -14             -12
# 2  ...               46          45                   1               0
# 3  ...              -46         -45                  -1               0
# 4  ...               15          13                  -8              -9
#
#   Scrums Successful Scrums Total Penalties Conceded Own Half  \
# 0                -8           -9                          -2
# 1                 8            9                           2
# 2                -3           -5                          -1
# 3                 3            5                           1
# 4                -4           -1                           0
#
#   Penalties Conceded Opp Half Yellow Cards Red Cards
# 0                          -3           -1         1
# 1                           3            1        -1
# 2                           0            0         0
# 3                           0            0         0
# 4                           3            0         0
#
# [5 rows x 33 columns]

# %% [markdown]
# # Next, explore what a mean performance is and for each metric, define a strength scalr or weakness depending on the rank

# %%
relative_df_ratio.columns
# Out:
# Index(['Date', 'Game ID', 'Team', 'Score', 'Possession - Overall',
#        'Possession - 1st half', 'Possession - 2nd half', 'Tries',
#        'Conversions', 'Penalties', 'Metres', 'Defenders Beaten',
#        'Clean breaks', 'Gain line Carries', 'Passes', 'Offloads',
#        'Turnovers won', 'Kicks from Hand', 'Rucks Won', 'Tackles Made',
#        'Tackles Missed', 'Goal Kicks Successful', 'Goal Kicks Attempted',
#        'Rucks Successful', 'Total Rucks', 'Lineouts Successful',
#        'Lineouts Thrown', 'Scrums Successful', 'Scrums Total',
#        'Penalties Conceded Own Half', 'Penalties Conceded Opp Half',
#        'Yellow Cards', 'Red Cards', 'Outcome'],
#       dtype='object')

# %%
# for each team average the relative performance% 
relative_df_ratio_average = relative_df_ratio.drop(['Game ID', 'Date'], axis=1).groupby('Team').median().reset_index()
#for each team, get in what percentil amongst the teams it lies. create a dict for each team
def get_rank(grouped_median_dict):
    dico = {}
    #for each team
    for col in grouped_median_dict.drop('Team',axis=1).columns:
        sorted = grouped_median_dict[[col, 'Team']].sort_values(ascending=False, by=col)
        dico[col] =list(sorted['Team'].values )
          #for ind in grouped_median_dict.index:
        #country = grouped_median_dict['Team'][ind]  
    #for each variable
    return dico

# %%
relative_df_ratio_average.head(5)
# Out:
#         Team     Score  Possession - Overall  Possession - 1st half  \
# 0  Argentina  0.590909                 0.530                  0.540
# 1  Australia  0.552703                 0.485                  0.555
# 2      Chile  0.133402                 0.455                  0.455
# 3    England  0.555556                 0.550                  0.540
# 4       Fiji  0.489362                 0.540                  0.530
#
#    Possession - 2nd half     Tries  Conversions  Penalties    Metres  \
# 0                  0.550  0.500000     0.500000   0.666667  0.568266
# 1                  0.440  0.666667     0.550000   0.500000  0.514206
# 2                  0.505  0.138889     0.071429   0.000000  0.367176
# 3                  0.460  0.500000     0.333333   0.571429  0.553991
# 4                  0.560  0.500000     0.500000   0.200000  0.508929
#
#    Defenders Beaten  ...  Total Rucks  Lineouts Successful  Lineouts Thrown  \
# 0          0.666667  ...     0.600000             0.611111         0.500000
# 1          0.459567  ...     0.529647             0.442424         0.421795
# 2          0.482886  ...     0.501082             0.436842         0.477730
# 3          0.482759  ...     0.485294             0.466667         0.458333
# 4          0.539683  ...     0.596685             0.555556         0.589744
#
#    Scrums Successful  Scrums Total  Penalties Conceded Own Half  \
# 0           0.466667      0.444444                     0.461538
# 1           0.409091      0.416667                     0.577381
# 2           0.279221      0.303846                     0.708333
# 3           0.600000      0.625000                     0.375000
# 4           0.562500      0.619048                     0.384615
#
#    Penalties Conceded Opp Half  Yellow Cards  Red Cards  Outcome
# 0                     0.500000      0.000000        0.0      1.0
# 1                     0.619048      0.000000        0.0      0.5
# 2                     0.452991      0.583333        0.0      0.0
# 3                     0.555556      0.000000        0.0      1.0
# 4                     0.400000      1.000000        0.0      0.0
#
# [5 rows x 32 columns]

# %%
#next, do max normalisation for each column, to have each value between 0 and 1. we<ll have percentages in function of the best performance
columns_to_apply = relative_df_ratio_average.columns.drop('Team')
relative_df_ratio_average[columns_to_apply] = relative_df_ratio_average[columns_to_apply].apply(lambda col: col / max(col))

# %%
relative_df_ratio_average.head(2)
# Out:
#         Team     Score  Possession - Overall  Possession - 1st half  \
# 0  Argentina  0.695549              0.929825               0.947368
# 1  Australia  0.650577              0.850877               0.973684
#
#    Possession - 2nd half     Tries  Conversions  Penalties    Metres  \
# 0               0.948276  0.500000         0.50   0.761905  0.905285
# 1               0.758621  0.666667         0.55   0.571429  0.819165
#
#    Defenders Beaten  ...  Total Rucks  Lineouts Successful  Lineouts Thrown  \
# 0          0.932569  ...     1.000000             1.000000         0.777778
# 1          0.642866  ...     0.882746             0.723967         0.656125
#
#    Scrums Successful  Scrums Total  Penalties Conceded Own Half  \
# 0           0.712727      0.704663                     0.651584
# 1           0.624793      0.660622                     0.815126
#
#    Penalties Conceded Opp Half  Yellow Cards  Red Cards  Outcome
# 0                     0.705882           0.0        0.0      1.0
# 1                     0.873950           0.0        0.0      0.5
#
# [2 rows x 32 columns]

# %%
test = relative_df_ratio_average[relative_df_ratio_average['Team']== team].drop('Team', axis=1).values
test[0]
# Out:
# array([0.31949   , 0.76315789, 0.81578947, 0.71551724, 0.26111111,
#        0.1984127 , 1.        , 0.56784481, 0.50497616, 0.56099456,
#        0.66927325, 0.61989234, 0.61111111, 0.60454545, 0.72788698,
#        0.7052736 , 0.86528799, 0.8233721 , 0.39823718, 0.41958042,
#        0.7052736 , 0.73398001, 0.5182618 , 0.57228535, 0.9472028 ,
#        0.97859136, 0.88067227, 0.68571429, 0.25      , 0.        ,
#        0.        ])

# %%
#do a test with one team
import plotly.express as px
import pandas as pd
team = 'Tonga'
df = relative_df_ratio_average[relative_df_ratio_average['Team']== team].drop('Team', axis=1)
fig = px.line_polar(df, r=df.values[0], theta= df.columns , line_close=True,  title='Relativ team Performance')
fig.update_layout(title_x=0.5)
fig.update_traces(fill='toself')
fig.show()

# %%
relative_df = create_relative_df(split_df)
relative_df.to_csv(current_dir+folder+'split_df_relative.csv', index=False)
relative_df_y = relative_df['Outcome']
relative_df_x = relative_df.drop(columns=['Outcome','Score','Tries', 'Conversions'])
#first do the PCA, apply embedding, and the LFA

# %%
label_encoder = LabelEncoder()
target_names =df['Team']
y_encoded = label_encoder.fit_transform(df['Team'])
pca = decomposition.PCA()

X=relative_df_x.drop(columns=['Date','Game ID', 'Team'])
pca.fit(X)
transformed = pca.transform(X)

# %%
cumulative_sum = np.cumsum(pca.explained_variance_ratio_, axis=0)
fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(1, 1, 1)
ax.plot(cumulative_sum)
ax.set_title('Cumulative Sum of PCA Explained Variance')
ax.set_ylabel('Explained Variance')
ax.set_xlabel('Number of Components')
# Out:
# Text(0.5, 0, 'Number of Components')

# %%
def top_N(cumulative_sum, percentage):
    topN = np.where(cumulative_sum > percentage)[0][0]
    print(f'{percentage*100}% in ' + '%d' % (topN+1) + ' components')
    return topN

top99 = top_N(cumulative_sum, 0.99)
transformed_99 = transformed[:,0:top99]
# Out:
# 99.0% in 16 components

# %%
lda = discriminant_analysis.LinearDiscriminantAnalysis()
lda.fit(np.array(transformed_99), np.array(y_encoded ))
transformed = lda.transform(transformed_99)

# %%
#split the variable 
plt.figure()
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf',
          '#aec7e8', '#ffbb78', '#98df8a', '#ff9896', '#c5b0d5',
          '#c49c94', '#f7b6d2', '#c7c7c7', '#dbdb8d', '#9edae5']
lw = 2

for color, i, target_name in zip(colors, range(20), target_names):
    plt.scatter(
        transformed[y_encoded == i, 0], transformed[y_encoded == i, 1], color=color, alpha=0.8, lw=lw, label=target_name
    )
plt.legend(loc="best", shadow=False, scatterpoints=1)
plt.title("PCA of IRIS dataset")
plt.show()

# %%
#test classification results
from sklearn.ensemble import HistGradientBoostingClassifier

clf = HistGradientBoostingClassifier(max_iter=100).fit(transformed, y_encoded)
clf.score(transformed, y_encoded)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 4
#       1 #test classification results
#       2 from sklearn.ensemble import HistGradientBoostingClassifier
# ----> 4 clf = HistGradientBoostingClassifier(max_iter=100).fit(transformed, y_encoded)
#       5 clf.score(transformed, y_encoded)
#
# File ~/venv/IFN703/lib/python3.10/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/venv/IFN703/lib/python3.10/site-packages/sklearn/ensemble/_hist_gradient_boosting/gradient_boosting.py:908, in BaseHistGradientBoosting.fit(self, X, y, sample_weight)
#     888 for k in range(self.n_trees_per_iteration_):
#     889     grower = TreeGrower(
#     890         X_binned=X_binned_train,
#     891         gradients=g_view[:, k],
#    (...)
#     906         n_threads=n_threads,
#     907     )
# --> 908     grower.grow()
#     910     acc_apply_split_time += grower.total_apply_split_time
#     911     acc_find_split_time += grower.total_find_split_time
#
# File ~/venv/IFN703/lib/python3.10/site-packages/sklearn/ensemble/_hist_gradient_boosting/grower.py:376, in TreeGrower.grow(self)
#     374 """Grow the tree, from root to leaves."""
#     375 while self.splittable_nodes:
# --> 376     self.split_next()
#     378 self._apply_shrinkage()
#
# File ~/venv/IFN703/lib/python3.10/site-packages/sklearn/ensemble/_hist_gradient_boosting/grower.py:613, in TreeGrower.split_next(self)
#     611 tic = time()
#     612 if should_split_left:
# --> 613     self._compute_best_split_and_push(left_child_node)
#     614 if should_split_right:
#     615     self._compute_best_split_and_push(right_child_node)
#
# File ~/venv/IFN703/lib/python3.10/site-packages/sklearn/ensemble/_hist_gradient_boosting/grower.py:446, in TreeGrower._compute_best_split_and_push(self, node)
#     437 def _compute_best_split_and_push(self, node):
#     438     """Compute the best possible split (SplitInfo) of a given node.
#     439
#     440     Also push it in the heap of splittable nodes if gain isn't zero.
#    (...)
#     443     (min_hessians_to_split, min_gain_to_split, min_samples_leaf)
#     444     """
# --> 446     node.split_info = self.splitter.find_node_split(
#     447         n_samples=node.n_samples,
#     448         histograms=node.histograms,
#     449         sum_gradients=node.sum_gradients,
#     450         sum_hessians=node.sum_hessians,
#     451         value=node.value,
#     452         lower_bound=node.children_lower_bound,
#     453         upper_bound=node.children_upper_bound,
#     454         allowed_features=node.allowed_features,
#     455     )
#     457     if node.split_info.gain <= 0:  # no valid split
#     458         self._finalize_leaf(node)
#
# KeyboardInterrupt:

# %%
#use neural network for embedding
