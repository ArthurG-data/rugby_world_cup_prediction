# %% [markdown]
# # The Library

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # The Necessary Files

# %%
current_dir = os.getcwd()
folder = '/data/results_international/'
result_file = 'adj_final_results.csv'
rubicology_file = 'all_games_RWC2023_fixed.csv'

# %% [markdown]
# # Expected score gap by elo gap/ relation between elo and score against or for?

# %%
result_df = pd.read_csv(current_dir+folder+result_file)
result_df['Date'] = pd.to_datetime(result_df['Date'])
result_df['point_gap'] = result_df.apply(lambda row: abs(row['home_score']-row['away_score']) , axis=1)
result_df.head(2)
# Out:
# Unnamed: 0                 int64
# Date              datetime64[ns]
# Tourn                     object
# Venue                     object
# home_team                 object
# away_team                 object
# home_score                 int64
# away_score                 int64
# Neut.                     object
# elo_home                 float64
# elo_away                 float64
# proba_home_win           float64
# elo_gap                  float64
# outcome                  float64
# point_gap                  int64
# dtype: object

# %%
#relationship between point gap and elo gap
result_positive_elo_gap = result_df
result_positive_elo_gap["elo_gap"] = result_positive_elo_gap["elo_gap"].abs()

# %%
elo_gap_ax = sns.lineplot(data=result_positive_elo_gap, x="point_gap", y="elo_gap")
elo_gap_ax.set(title='Relationship Between score gap and Elo Gap')
elo_gap_ax.set(xlabel='Point Gap', ylabel='Elo Gap')
# Out:
# [Text(0.5, 0, 'Point Gap'), Text(0, 0.5, 'Elo Gap')]

# %%
#select only the games between the wc, build simple linear model to find relation between point gap and score ga_train = p
result_positive_elo_gap_train =  result_positive_elo_gap[(result_positive_elo_gap['Tourn']!= 'WC')&(result_positive_elo_gap['Date'].dt.year!= 2023)]
result_positive_elo_gap_test =  result_positive_elo_gap[(result_positive_elo_gap['Tourn']== 'WC')&(result_positive_elo_gap['Date'].dt.year== 2023)]

#estimate point gap
X = np.array(result_positive_elo_gap_train['elo_gap']).reshape(-1,1)
y= np.array(result_positive_elo_gap_train['point_gap']).reshape(-1,1)
X_test = np.array(result_positive_elo_gap_test['elo_gap']).reshape(-1,1)
Y_test = np.array(result_positive_elo_gap_test['point_gap']).reshape(-1,1)
predict_score_gap = LinearRegression().fit(X, y)

# %%
#plot the elo gaps
sns.histplot(data=result_positive_elo_gap_test, x='elo_gap')
# Out:
# <Axes: xlabel='elo_gap', ylabel='Count'>

# %%
#evaluate models
predicted_y = predict_score_gap.predict(X_test)
mse = 0
for i in range(len(X_test)):
    mse += (predicted_y[i] - Y_test[i])**2
    mse = mse/len(X_test)
print(f'mse: {mse}')
result_positive_elo_gap_test['predicted_gap'] = predicted_y
# Out:
# mse: [2.88511477]

# %% [markdown]
# # First exploration: Any upsets?

# %%
#Conditions on wins
condition_1 = result_positive_elo_gap_test['elo_gap']>200
condition_2 = (result_positive_elo_gap_test['proba_home_win']<0.5) & (result_positive_elo_gap_test['outcome']>0)
condition_3 = (result_positive_elo_gap_test['proba_home_win']>0.5) & (result_positive_elo_gap_test['outcome']<1)
#conditions on score 
condition_4 = result_positive_elo_gap_test['point_gap'] <result_positive_elo_gap_test['predicted_gap']-14
## we will look at score gap smaller than expectd
upsets = result_positive_elo_gap_test[((condition_1) &(condition_2 | condition_3))|condition_4]
upsets
# Out:
#       Unnamed: 0       Date Tourn Venue home_team away_team  home_score  \
# 2346        3615 2023-09-10    WC    Na       SOU       SCO          18
# 2348        3617 2023-09-14    WC    Na       FRA       URU          27
# 2359        3628 2023-09-23    WC    Na       SOU       IRE           8
# 2368        3637 2023-09-30    WC    Na       FIJ       GEO          17
# 2375        3644 2023-10-07    WC    Na       ENG       SAM          18
# 2377        3646 2023-10-08    WC    Na       FIJ       POR          23
# 2381        3650 2023-10-14    WC    Na       NEW       IRE          28
# 2383        3652 2023-10-15    WC    Na       FRA       SOU          28
#
#       away_score  Neut.     elo_home     elo_away  proba_home_win  \
# 2346           3   True  1208.134005  1504.432349        0.153731
# 2348          12   True  1822.881419   507.699960        0.999485
# 2359          13   True  1378.900742  1929.085604        0.040422
# 2368          12   True  1195.792223   623.781906        0.964179
# 2375          17   True  1464.957413   908.430369        0.960971
# 2377          24   True  1199.867242   578.007518        0.972873
# 2381          24  False  1470.130780  1940.276062        0.062598
# 2383          29   True  1823.898789  1375.959799        0.929468
#
#           elo_gap  outcome  point_gap  predicted_gap
# 2346   296.298344      1.0         15      15.468884
# 2348  1315.181458      1.0         15      40.032634
# 2359   550.184862      0.0          5      21.589709
# 2368   572.010316      1.0          5      22.115888
# 2375   556.527044      1.0          1      21.742609
# 2377   621.859723      0.0          1      23.317682
# 2381   470.145282      1.0          4      19.660074
# 2383   447.938989      0.0          1      19.124713
